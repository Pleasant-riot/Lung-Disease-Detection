# %%
# basic module
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import shutil
import glob
import time
import pickle

plt.style.use('seaborn-dark')
# %config InlineBackend.figure_format = 'retina'
pd.options.display.max_rows = 20
pd.options.display.max_columns = 20

plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = False


# image module
import cv2
from pydicom import dcmread
import pylibjpeg
from PIL import Image
import pydicom as dcm
from pydicom import dcmread
from pydicom.data import get_testdata_file



# dataset
df = pd.read_csv('dataset.csv',index_col=0)

# %%
dcmpath = list(df['orginal_dcm_file'])

# %%
test= dcmpath[0]
test
# Out:
# '/home/ncp/workspace/data/train/04.신생아호흡곤란증후군/A1.0-2개월/H05_00019_02/org/H05_00019_02.dcm'

# %%
dcm = dcmread(test).pixel_array

# %%
fname = test.replace('.dcm','.png')
# Out:
# '/home/ncp/workspace/data/train/04.신생아호흡곤란증후군/A1.0-2개월/H05_00019_02/org/H05_00019_02.png'

# %%
plt.imsave(fname,dcm)

# %%
plt.imshow(dcm)

# %%
A = cv2.imread('H05_00019_02.png')
plt.imshow(A)

# %%
A.shape
# Out:
# (1131, 760, 3)

# %%
correct = []
error = []
for dcm in dcmpath:
    try:
        dcm_img = dcmread(dcm).pixel_array
        fname = dcm.replace('.dcm','.png')
        plt.imsave(fname,dcm_img)
        correct.append(fname)
        print(fname.'      [완료]')
        
    except Exception as e:
        print('\n',e)
        print(dcm,'      [오류] ','\n')
        error.append(dcm)

# %%
dcm='/home/ncp/workspace/data/train/05.폐렴/A3.6-10세/H07_01654_01/org/H07_01654_01.dcm'

# %%
dcm_img = dcmread(dcm).pixel_array
fname = dcm.replace('.dcm','.png')
plt.imsave(fname,dcm_img)
#         correct.append(fname)
print(fname,'      [완료]')
# Out:
# /home/ncp/workspace/data/train/05.폐렴/A3.6-10세/H07_01654_01/org/H07_01654_01.png       [완료]

# %%
A =cv2.imread('/home/ncp/workspace/data/train/05.폐렴/A3.6-10세/H07_01654_01/org/H07_01654_01.png')
plt.imshow(A)
