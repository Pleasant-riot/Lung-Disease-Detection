# %% [markdown]
# ### MODULE IMPORT

# %%
import os
import shutil

# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

from glob import glob
from tqdm import tqdm

# %% [markdown]
# ##### PATH

# %%
# INPUT_DIR = os.path.join("..", "input")/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input
INPUT_DIR = '/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input'

SEGMENTATION_DIR = os.path.join(INPUT_DIR, "segmentation")
SEGMENTATION_TEST_DIR = os.path.join(SEGMENTATION_DIR, "test")
SEGMENTATION_TRAIN_DIR = os.path.join(SEGMENTATION_DIR, "train")
SEGMENTATION_AUG_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "augmentation")
SEGMENTATION_IMAGE_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "image")
SEGMENTATION_MASK_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "mask")
SEGMENTATION_DILATE_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "dilate")
SEGMENTATION_SOURCE_DIR = os.path.join(INPUT_DIR, \
                                       "pulmonary-chest-xray-abnormalities")

SHENZHEN_TRAIN_DIR = os.path.join(SEGMENTATION_SOURCE_DIR, "ChinaSet_AllFiles", \
                                  "ChinaSet_AllFiles")
SHENZHEN_IMAGE_DIR = os.path.join(SHENZHEN_TRAIN_DIR, "CXR_png")
SHENZHEN_MASK_DIR = os.path.join(INPUT_DIR, "shcxr-lung-mask", "mask", "mask")

MONTGOMERY_TRAIN_DIR = os.path.join(SEGMENTATION_SOURCE_DIR, \
                                    "Montgomery", "MontgomerySet")
MONTGOMERY_IMAGE_DIR = os.path.join(MONTGOMERY_TRAIN_DIR, "CXR_png")
MONTGOMERY_LEFT_MASK_DIR = os.path.join(MONTGOMERY_TRAIN_DIR, \
                                        "ManualMask", "leftMask")
MONTGOMERY_RIGHT_MASK_DIR = os.path.join(MONTGOMERY_TRAIN_DIR, \
                                         "ManualMask", "rightMask")

DILATE_KERNEL = np.ones((15, 15), np.uint8)

BATCH_SIZE =2

#Prod
EPOCHS = 100

#Desv
#EPOCHS=16

# %%
# !mkdir /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation
# !mkdir /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test
# !mkdir /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/train
# !mkdir /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/augmentation
# !mkdir /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/image
# !mkdir /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/mask
# !mkdir /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/dilate

# %%
print('SEGMENTATION_DIR              ',SEGMENTATION_DIR)
print('SEGMENTATION_TEST_DIR              ',SEGMENTATION_TEST_DIR)
print('SEGMENTATION_TRAIN_DIR              ',SEGMENTATION_TRAIN_DIR)
print('SEGMENTATION_AUG_DIR              ',SEGMENTATION_AUG_DIR)
print('SEGMENTATION_IMAGE_DIR              ',SEGMENTATION_IMAGE_DIR)
print('SEGMENTATION_MASK_DIR              ',SEGMENTATION_MASK_DIR)
print('SEGMENTATION_DILATE_DIR              ',SEGMENTATION_DILATE_DIR)
print('SEGMENTATION_SOURCE_DIR              ',SEGMENTATION_SOURCE_DIR)
print('SHENZHEN_TRAIN_DIR              ',SHENZHEN_TRAIN_DIR)
print('SHENZHEN_IMAGE_DIR              ',SHENZHEN_IMAGE_DIR)
print('SHENZHEN_MASK_DIR              ',SHENZHEN_MASK_DIR)
print('MONTGOMERY_TRAIN_DIR              ',MONTGOMERY_TRAIN_DIR)
print('MONTGOMERY_IMAGE_DIR              ',MONTGOMERY_IMAGE_DIR)
print('MONTGOMERY_LEFT_MASK_DIR              ',MONTGOMERY_LEFT_MASK_DIR)
print('MONTGOMERY_RIGHT_MASK_DIR              ',MONTGOMERY_RIGHT_MASK_DIR)
# Out:
# SEGMENTATION_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation
# SEGMENTATION_TEST_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test
# SEGMENTATION_TRAIN_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/train
# SEGMENTATION_AUG_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/train/augmentation
# SEGMENTATION_IMAGE_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/train/image
# SEGMENTATION_MASK_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/train/mask
# SEGMENTATION_DILATE_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/train/dilate
# SEGMENTATION_SOURCE_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/pulmonary-chest-xray-abnormalities
# SHENZHEN_TRAIN_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles
# SHENZHEN_IMAGE_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/CXR_png
# SHENZHEN_MASK_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/shcxr-lung-mask/mask/mask
# MONTGOMERY_TRAIN_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet
# MONTGOMERY_IMAGE_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png
# MONTGOMERY_LEFT_MASK_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/ManualMask/leftMask
# MONTGOMERY_RIGHT_MASK_DIR               /content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/ManualMask/rightMask

# %%
print(len(MONTGOMERY_TRAIN_DIR))
print(len(MONTGOMERY_IMAGE_DIR))
print(len(MONTGOMERY_LEFT_MASK_DIR))
print(len(SHENZHEN_IMAGE_DIR))
# Out:
# 123
# 131
# 143
# 142

# %% [markdown]
# ## TRAINING FILE_MONT

# %%
montgomery_left_mask_dir = glob(os.path.join(MONTGOMERY_LEFT_MASK_DIR, '*.png'))
montgomery_test = montgomery_left_mask_dir[0:50]
montgomery_train= montgomery_left_mask_dir[50:]

for left_image_file in tqdm(montgomery_left_mask_dir):
    base_file = os.path.basename(left_image_file)
    image_file = os.path.join(MONTGOMERY_IMAGE_DIR, base_file)
    right_image_file = os.path.join(MONTGOMERY_RIGHT_MASK_DIR, base_file)

    image = cv2.imread(image_file)
    left_mask = cv2.imread(left_image_file, cv2.IMREAD_GRAYSCALE)
    right_mask = cv2.imread(right_image_file, cv2.IMREAD_GRAYSCALE)
    
    image = cv2.resize(image, (512, 512))
    left_mask = cv2.resize(left_mask, (512, 512))
    right_mask = cv2.resize(right_mask, (512, 512))
    
    mask = np.maximum(left_mask, right_mask)
    mask_dilate = cv2.dilate(mask, DILATE_KERNEL, iterations=1)
    
    if (left_image_file in montgomery_train):
        cv2.imwrite(os.path.join(SEGMENTATION_IMAGE_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_MASK_DIR, base_file), \
                    mask)
        cv2.imwrite(os.path.join(SEGMENTATION_DILATE_DIR, base_file), \
                    mask_dilate)
    else:
        filename, fileext = os.path.splitext(base_file)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_mask%s" % (filename, fileext)), mask)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)
# Out:
# 100%|██████████| 138/138 [03:40<00:00,  1.60s/it]

# %%
def add_colored_dilate(image, mask_image, dilate_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    dilate_image_gray = cv2.cvtColor(dilate_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    dilate = cv2.bitwise_and(dilate_image, dilate_image, mask=dilate_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])
    dilate_coord = np.where(dilate!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]
    dilate[dilate_coord[0],dilate_coord[1],:] = [0,0,255]

    ret = cv2.addWeighted(image, 0.7, dilate, 0.3, 0)
    ret = cv2.addWeighted(ret, 0.7, mask, 0.3, 0)

    return ret

def add_colored_mask(image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(image, 0.7, mask, 0.3, 0)

    return ret

def diff_mask(ref_image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(ref_image, 0.7, mask, 0.3, 0)
    return ret

# %%
base_file = os.path.basename(montgomery_train[0])

image_file = os.path.join(SEGMENTATION_IMAGE_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_MASK_DIR, base_file)
dilate_image_file = os.path.join(SEGMENTATION_DILATE_DIR, base_file)

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
                          
fig, axs = plt.subplots(2, 4, figsize=(15, 8))

axs[0, 0].set_title("X-Ray")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(montgomery_test[0])
filename, fileext = os.path.splitext(base_file)
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))
dilate_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext))

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %% [markdown]
# ### THRAINING FILE SHENZEHN

# %%
shenzhen_mask_dir = glob(os.path.join(SHENZHEN_MASK_DIR, '*.png'))
shenzhen_test = shenzhen_mask_dir[0:50]
shenzhen_train= shenzhen_mask_dir[50:]

for mask_file in tqdm(shenzhen_mask_dir):
    base_file = os.path.basename(mask_file).replace("_mask", "")
    image_file = os.path.join(SHENZHEN_IMAGE_DIR, base_file)

    image = cv2.imread(image_file)
    mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)
        
    image = cv2.resize(image, (512, 512))
    mask = cv2.resize(mask, (512, 512))
    mask_dilate = cv2.dilate(mask, DILATE_KERNEL, iterations=1)
    
    if (mask_file in shenzhen_train):
        cv2.imwrite(os.path.join(SEGMENTATION_IMAGE_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_MASK_DIR, base_file), \
                    mask)
        cv2.imwrite(os.path.join(SEGMENTATION_DILATE_DIR, base_file), \
                    mask_dilate)
    else:
        filename, fileext = os.path.splitext(base_file)

        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_mask%s" % (filename, fileext)), mask)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)
# Out:
# 100%|██████████| 566/566 [12:40<00:00,  1.34s/it]

# %%
base_file = os.path.basename(shenzhen_train[0].replace("_mask", ""))

image_file = os.path.join(SEGMENTATION_IMAGE_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_MASK_DIR, base_file)
dilate_image_file = os.path.join(SEGMENTATION_DILATE_DIR, base_file)

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
                          
fig, axs = plt.subplots(2, 4, figsize=(15, 8))

axs[0, 0].set_title("X-Ray")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(shenzhen_test[0].replace("_mask", ""))
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
filename, fileext = os.path.splitext(base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))

filename, fileext = os.path.splitext(base_file)
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))
dilate_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext))

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %% [markdown]
# ##### TRAIN FILE CHECK

# %%
train_files = glob(os.path.join(SEGMENTATION_IMAGE_DIR, "*.png"))
test_files = glob(os.path.join(SEGMENTATION_TEST_DIR, "*.png"))
mask_files = glob(os.path.join(SEGMENTATION_MASK_DIR, "*.png"))
dilate_files = glob(os.path.join(SEGMENTATION_DILATE_DIR, "*.png"))

(len(train_files), \
 len(test_files), \
 len(mask_files), \
 len(dilate_files))
# Out:
# (604, 300, 604, 604)

# %%
train_files = glob(os.path.join(SEGMENTATION_IMAGE_DIR, "*.png"))
test_files = glob(os.path.join(SEGMENTATION_TEST_DIR, "*.png"))
mask_files = glob(os.path.join(SEGMENTATION_MASK_DIR, "*.png"))
dilate_files = glob(os.path.join(SEGMENTATION_DILATE_DIR, "*.png"))

(len(train_files), \
 len(test_files), \
 len(mask_files), \
 len(dilate_files))
# Out:
# (604, 300, 604, 604)

# %%
def train_generator(batch_size, train_path, image_folder, mask_folder, aug_dict,
        image_color_mode="grayscale",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
def test_load_image(test_file, target_size=(256,256)):
    img = cv2.imread(test_file, cv2.IMREAD_GRAYSCALE)
    img = img / 255
    img = cv2.resize(img, target_size)
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,) + img.shape)
    return img

def test_generator(test_files, target_size=(256,256)):
    for test_file in test_files:
        yield test_load_image(test_file, target_size)
        
def save_result(save_path, npyfile, test_files):
    for i, item in enumerate(npyfile):
        result_file = test_files[i]
        img = (item[:, :, 0] * 255.).astype(np.uint8)

        filename, fileext = os.path.splitext(os.path.basename(result_file))

        result_file = os.path.join(save_path, "%s_predict%s" % (filename, fileext))

        cv2.imwrite(result_file, img)

# %%
def add_suffix(base_file, suffix):
    filename, fileext = os.path.splitext(base_file)
    return "%s_%s%s" % (filename, suffix, fileext)

test_files = [test_file for test_file in glob(os.path.join(SEGMENTATION_TEST_DIR, "*.png")) \
              if ("_mask" not in test_file \
                  and "_dilate" not in test_file \
                  and "_predict" not in test_file)]

validation_data = (test_load_image(test_files[0], target_size=(512, 512)),
                    test_load_image(add_suffix(test_files[0], "dilate"), target_size=(512, 512)))

len(test_files), len(validation_data)
# Out:
# (100, 2)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(BATCH_SIZE,
                            SEGMENTATION_TRAIN_DIR,
                            'image',
                            'dilate', 
                            train_generator_args,
                            target_size=(512,512),
                            save_to_dir=os.path.abspath(SEGMENTATION_AUG_DIR))

model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, \
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()


model_EarlyStopping = EarlyStopping(monitor='loss', patience=5)

model_checkpoint = ModelCheckpoint('/content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5', 
                                   monitor='loss', 
                                   verbose=1, 
                                   save_best_only=True)

history = model.fit_generator(train_gen,
                              steps_per_epoch=len(train_files) / BATCH_SIZE,    
                              epochs=EPOCHS, 
                              callbacks=[model_EarlyStopping,model_checkpoint],
                              validation_data = validation_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  320         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d_1[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_4[0][0]']
#                                 8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 256)  524544     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 12  131200     ['conv2d_11[0][0]']
#  spose)                         8)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_1[0][0]',
#                                 6)                                'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_1[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_12[0][0]']
#                                 8)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 64  32832      ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 32  8224       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Found 604 images belonging to 1 classes.
# Found 604 images belonging to 1 classes.
# Epoch 1/100
# 302/302 [==============================] - ETA: 0s - loss: -0.3817 - dice_coef: 0.3817 - binary_accuracy: 0.4980
# Epoch 00001: loss improved from inf to -0.38173, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 72s 203ms/step - loss: -0.3817 - dice_coef: 0.3817 - binary_accuracy: 0.4980 - val_loss: -0.3120 - val_dice_coef: 0.3120 - val_binary_accuracy: 0.6437
# Epoch 2/100
# 302/302 [==============================] - ETA: 0s - loss: -0.5046 - dice_coef: 0.5046 - binary_accuracy: 0.4633
# Epoch 00002: loss improved from -0.38173 to -0.50459, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 59s 197ms/step - loss: -0.5046 - dice_coef: 0.5046 - binary_accuracy: 0.4633 - val_loss: -0.5503 - val_dice_coef: 0.5503 - val_binary_accuracy: 0.7202
# Epoch 3/100
# 302/302 [==============================] - ETA: 0s - loss: -0.6279 - dice_coef: 0.6279 - binary_accuracy: 0.6555
# Epoch 00003: loss improved from -0.50459 to -0.62788, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.6279 - dice_coef: 0.6279 - binary_accuracy: 0.6555 - val_loss: -0.5815 - val_dice_coef: 0.5815 - val_binary_accuracy: 0.8211
# Epoch 4/100
# 302/302 [==============================] - ETA: 0s - loss: -0.6770 - dice_coef: 0.6770 - binary_accuracy: 0.7308
# Epoch 00004: loss improved from -0.62788 to -0.67701, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.6770 - dice_coef: 0.6770 - binary_accuracy: 0.7308 - val_loss: -0.6811 - val_dice_coef: 0.6811 - val_binary_accuracy: 0.8286
# Epoch 5/100
# 302/302 [==============================] - ETA: 0s - loss: -0.6874 - dice_coef: 0.6874 - binary_accuracy: 0.7461
# Epoch 00005: loss improved from -0.67701 to -0.68740, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.6874 - dice_coef: 0.6874 - binary_accuracy: 0.7461 - val_loss: -0.6064 - val_dice_coef: 0.6064 - val_binary_accuracy: 0.8575
# Epoch 6/100
# 302/302 [==============================] - ETA: 0s - loss: -0.7089 - dice_coef: 0.7089 - binary_accuracy: 0.7747
# Epoch 00006: loss improved from -0.68740 to -0.70886, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.7089 - dice_coef: 0.7089 - binary_accuracy: 0.7747 - val_loss: -0.7618 - val_dice_coef: 0.7618 - val_binary_accuracy: 0.9019
# Epoch 7/100
# 302/302 [==============================] - ETA: 0s - loss: -0.8407 - dice_coef: 0.8407 - binary_accuracy: 0.9041
# Epoch 00007: loss improved from -0.70886 to -0.84067, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 59s 197ms/step - loss: -0.8407 - dice_coef: 0.8407 - binary_accuracy: 0.9041 - val_loss: -0.8251 - val_dice_coef: 0.8251 - val_binary_accuracy: 0.9249
# Epoch 8/100
# 302/302 [==============================] - ETA: 0s - loss: -0.8654 - dice_coef: 0.8654 - binary_accuracy: 0.9185
# Epoch 00008: loss improved from -0.84067 to -0.86543, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 59s 197ms/step - loss: -0.8654 - dice_coef: 0.8654 - binary_accuracy: 0.9185 - val_loss: -0.8369 - val_dice_coef: 0.8369 - val_binary_accuracy: 0.9371
# Epoch 9/100
# 302/302 [==============================] - ETA: 0s - loss: -0.8767 - dice_coef: 0.8767 - binary_accuracy: 0.9255
# Epoch 00009: loss improved from -0.86543 to -0.87675, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.8767 - dice_coef: 0.8767 - binary_accuracy: 0.9255 - val_loss: -0.8827 - val_dice_coef: 0.8827 - val_binary_accuracy: 0.9527
# Epoch 10/100
# 302/302 [==============================] - ETA: 0s - loss: -0.8830 - dice_coef: 0.8830 - binary_accuracy: 0.9290
# Epoch 00010: loss improved from -0.87675 to -0.88297, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 201ms/step - loss: -0.8830 - dice_coef: 0.8830 - binary_accuracy: 0.9290 - val_loss: -0.8910 - val_dice_coef: 0.8910 - val_binary_accuracy: 0.9520
# Epoch 11/100
# 302/302 [==============================] - ETA: 0s - loss: -0.8965 - dice_coef: 0.8965 - binary_accuracy: 0.9376
# Epoch 00011: loss improved from -0.88297 to -0.89655, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.8965 - dice_coef: 0.8965 - binary_accuracy: 0.9376 - val_loss: -0.8594 - val_dice_coef: 0.8594 - val_binary_accuracy: 0.9400
# Epoch 12/100
# 302/302 [==============================] - ETA: 0s - loss: -0.8954 - dice_coef: 0.8954 - binary_accuracy: 0.9365
# Epoch 00012: loss did not improve from -0.89655
# 302/302 [==============================] - 60s 200ms/step - loss: -0.8954 - dice_coef: 0.8954 - binary_accuracy: 0.9365 - val_loss: -0.9175 - val_dice_coef: 0.9175 - val_binary_accuracy: 0.9667
# Epoch 13/100
# 302/302 [==============================] - ETA: 0s - loss: -0.8965 - dice_coef: 0.8965 - binary_accuracy: 0.9377
# Epoch 00013: loss did not improve from -0.89655
# 302/302 [==============================] - 60s 199ms/step - loss: -0.8965 - dice_coef: 0.8965 - binary_accuracy: 0.9377 - val_loss: -0.8506 - val_dice_coef: 0.8506 - val_binary_accuracy: 0.9378
# Epoch 14/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9080 - dice_coef: 0.9080 - binary_accuracy: 0.9443
# Epoch 00014: loss improved from -0.89655 to -0.90805, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9080 - dice_coef: 0.9080 - binary_accuracy: 0.9443 - val_loss: -0.8773 - val_dice_coef: 0.8773 - val_binary_accuracy: 0.9489
# Epoch 15/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9136 - dice_coef: 0.9136 - binary_accuracy: 0.9480
# Epoch 00015: loss improved from -0.90805 to -0.91356, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 61s 202ms/step - loss: -0.9136 - dice_coef: 0.9136 - binary_accuracy: 0.9480 - val_loss: -0.8850 - val_dice_coef: 0.8850 - val_binary_accuracy: 0.9513
# Epoch 16/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9134 - dice_coef: 0.9134 - binary_accuracy: 0.9478
# Epoch 00016: loss did not improve from -0.91356
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9134 - dice_coef: 0.9134 - binary_accuracy: 0.9478 - val_loss: -0.9176 - val_dice_coef: 0.9176 - val_binary_accuracy: 0.9668
# Epoch 17/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9192 - dice_coef: 0.9192 - binary_accuracy: 0.9510
# Epoch 00017: loss improved from -0.91356 to -0.91917, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9192 - dice_coef: 0.9192 - binary_accuracy: 0.9510 - val_loss: -0.9081 - val_dice_coef: 0.9081 - val_binary_accuracy: 0.9613
# Epoch 18/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9220 - dice_coef: 0.9220 - binary_accuracy: 0.9530
# Epoch 00018: loss improved from -0.91917 to -0.92198, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9220 - dice_coef: 0.9220 - binary_accuracy: 0.9530 - val_loss: -0.8534 - val_dice_coef: 0.8534 - val_binary_accuracy: 0.9420
# Epoch 19/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9236 - dice_coef: 0.9236 - binary_accuracy: 0.9538
# Epoch 00019: loss improved from -0.92198 to -0.92361, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9236 - dice_coef: 0.9236 - binary_accuracy: 0.9538 - val_loss: -0.8470 - val_dice_coef: 0.8470 - val_binary_accuracy: 0.9400
# Epoch 20/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9264 - dice_coef: 0.9264 - binary_accuracy: 0.9555
# Epoch 00020: loss improved from -0.92361 to -0.92644, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9264 - dice_coef: 0.9264 - binary_accuracy: 0.9555 - val_loss: -0.8651 - val_dice_coef: 0.8651 - val_binary_accuracy: 0.9440
# Epoch 21/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9290 - dice_coef: 0.9290 - binary_accuracy: 0.9572
# Epoch 00021: loss improved from -0.92644 to -0.92897, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9290 - dice_coef: 0.9290 - binary_accuracy: 0.9572 - val_loss: -0.8888 - val_dice_coef: 0.8888 - val_binary_accuracy: 0.9543
# Epoch 22/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9331 - dice_coef: 0.9331 - binary_accuracy: 0.9596
# Epoch 00022: loss improved from -0.92897 to -0.93315, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9331 - dice_coef: 0.9331 - binary_accuracy: 0.9596 - val_loss: -0.8486 - val_dice_coef: 0.8486 - val_binary_accuracy: 0.9356
# Epoch 23/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9316 - dice_coef: 0.9316 - binary_accuracy: 0.9585
# Epoch 00023: loss did not improve from -0.93315
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9316 - dice_coef: 0.9316 - binary_accuracy: 0.9585 - val_loss: -0.8785 - val_dice_coef: 0.8785 - val_binary_accuracy: 0.9497
# Epoch 24/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9354 - dice_coef: 0.9354 - binary_accuracy: 0.9609
# Epoch 00024: loss improved from -0.93315 to -0.93543, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9354 - dice_coef: 0.9354 - binary_accuracy: 0.9609 - val_loss: -0.8892 - val_dice_coef: 0.8892 - val_binary_accuracy: 0.9536
# Epoch 25/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9335 - dice_coef: 0.9335 - binary_accuracy: 0.9598
# Epoch 00025: loss did not improve from -0.93543
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9335 - dice_coef: 0.9335 - binary_accuracy: 0.9598 - val_loss: -0.8990 - val_dice_coef: 0.8990 - val_binary_accuracy: 0.9590
# Epoch 26/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9390 - dice_coef: 0.9390 - binary_accuracy: 0.9631
# Epoch 00026: loss improved from -0.93543 to -0.93899, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9390 - dice_coef: 0.9390 - binary_accuracy: 0.9631 - val_loss: -0.8932 - val_dice_coef: 0.8932 - val_binary_accuracy: 0.9561
# Epoch 27/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9402 - dice_coef: 0.9402 - binary_accuracy: 0.9637
# Epoch 00027: loss improved from -0.93899 to -0.94019, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9402 - dice_coef: 0.9402 - binary_accuracy: 0.9637 - val_loss: -0.9035 - val_dice_coef: 0.9035 - val_binary_accuracy: 0.9602
# Epoch 28/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9416 - dice_coef: 0.9416 - binary_accuracy: 0.9646
# Epoch 00028: loss improved from -0.94019 to -0.94162, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9416 - dice_coef: 0.9416 - binary_accuracy: 0.9646 - val_loss: -0.9070 - val_dice_coef: 0.9070 - val_binary_accuracy: 0.9620
# Epoch 29/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9420 - dice_coef: 0.9420 - binary_accuracy: 0.9649
# Epoch 00029: loss improved from -0.94162 to -0.94203, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9420 - dice_coef: 0.9420 - binary_accuracy: 0.9649 - val_loss: -0.9041 - val_dice_coef: 0.9041 - val_binary_accuracy: 0.9611
# Epoch 30/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9444 - dice_coef: 0.9444 - binary_accuracy: 0.9664
# Epoch 00030: loss improved from -0.94203 to -0.94444, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9444 - dice_coef: 0.9444 - binary_accuracy: 0.9664 - val_loss: -0.9428 - val_dice_coef: 0.9428 - val_binary_accuracy: 0.9750
# Epoch 31/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9449 - dice_coef: 0.9449 - binary_accuracy: 0.9666
# Epoch 00031: loss improved from -0.94444 to -0.94492, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9449 - dice_coef: 0.9449 - binary_accuracy: 0.9666 - val_loss: -0.9134 - val_dice_coef: 0.9134 - val_binary_accuracy: 0.9644
# Epoch 32/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9446 - dice_coef: 0.9446 - binary_accuracy: 0.9663
# Epoch 00032: loss did not improve from -0.94492
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9446 - dice_coef: 0.9446 - binary_accuracy: 0.9663 - val_loss: -0.9643 - val_dice_coef: 0.9643 - val_binary_accuracy: 0.9842
# Epoch 33/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9431 - dice_coef: 0.9431 - binary_accuracy: 0.9656
# Epoch 00033: loss did not improve from -0.94492
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9431 - dice_coef: 0.9431 - binary_accuracy: 0.9656 - val_loss: -0.9523 - val_dice_coef: 0.9523 - val_binary_accuracy: 0.9796
# Epoch 34/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9476 - dice_coef: 0.9476 - binary_accuracy: 0.9681
# Epoch 00034: loss improved from -0.94492 to -0.94757, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9476 - dice_coef: 0.9476 - binary_accuracy: 0.9681 - val_loss: -0.9528 - val_dice_coef: 0.9528 - val_binary_accuracy: 0.9794
# Epoch 35/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9477 - dice_coef: 0.9477 - binary_accuracy: 0.9681
# Epoch 00035: loss improved from -0.94757 to -0.94766, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 61s 201ms/step - loss: -0.9477 - dice_coef: 0.9477 - binary_accuracy: 0.9681 - val_loss: -0.9315 - val_dice_coef: 0.9315 - val_binary_accuracy: 0.9689
# Epoch 36/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9492 - dice_coef: 0.9492 - binary_accuracy: 0.9691
# Epoch 00036: loss improved from -0.94766 to -0.94919, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9492 - dice_coef: 0.9492 - binary_accuracy: 0.9691 - val_loss: -0.9553 - val_dice_coef: 0.9553 - val_binary_accuracy: 0.9807
# Epoch 37/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9489 - dice_coef: 0.9489 - binary_accuracy: 0.9688
# Epoch 00037: loss did not improve from -0.94919
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9489 - dice_coef: 0.9489 - binary_accuracy: 0.9688 - val_loss: -0.9574 - val_dice_coef: 0.9574 - val_binary_accuracy: 0.9815
# Epoch 38/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9480 - dice_coef: 0.9480 - binary_accuracy: 0.9685
# Epoch 00038: loss did not improve from -0.94919
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9480 - dice_coef: 0.9480 - binary_accuracy: 0.9685 - val_loss: -0.9476 - val_dice_coef: 0.9476 - val_binary_accuracy: 0.9765
# Epoch 39/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9502 - dice_coef: 0.9502 - binary_accuracy: 0.9697
# Epoch 00039: loss improved from -0.94919 to -0.95019, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9502 - dice_coef: 0.9502 - binary_accuracy: 0.9697 - val_loss: -0.9703 - val_dice_coef: 0.9703 - val_binary_accuracy: 0.9867
# Epoch 40/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9500 - dice_coef: 0.9500 - binary_accuracy: 0.9695
# Epoch 00040: loss did not improve from -0.95019
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9500 - dice_coef: 0.9500 - binary_accuracy: 0.9695 - val_loss: -0.9512 - val_dice_coef: 0.9512 - val_binary_accuracy: 0.9787
# Epoch 41/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9516 - dice_coef: 0.9516 - binary_accuracy: 0.9705
# Epoch 00041: loss improved from -0.95019 to -0.95157, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9516 - dice_coef: 0.9516 - binary_accuracy: 0.9705 - val_loss: -0.9503 - val_dice_coef: 0.9503 - val_binary_accuracy: 0.9770
# Epoch 42/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9521 - dice_coef: 0.9521 - binary_accuracy: 0.9709
# Epoch 00042: loss improved from -0.95157 to -0.95209, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9521 - dice_coef: 0.9521 - binary_accuracy: 0.9709 - val_loss: -0.9559 - val_dice_coef: 0.9559 - val_binary_accuracy: 0.9800
# Epoch 43/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9527 - dice_coef: 0.9527 - binary_accuracy: 0.9712
# Epoch 00043: loss improved from -0.95209 to -0.95265, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9527 - dice_coef: 0.9527 - binary_accuracy: 0.9712 - val_loss: -0.9735 - val_dice_coef: 0.9735 - val_binary_accuracy: 0.9881
# Epoch 44/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9524 - dice_coef: 0.9524 - binary_accuracy: 0.9711
# Epoch 00044: loss did not improve from -0.95265
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9524 - dice_coef: 0.9524 - binary_accuracy: 0.9711 - val_loss: -0.9519 - val_dice_coef: 0.9519 - val_binary_accuracy: 0.9794
# Epoch 45/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9524 - dice_coef: 0.9524 - binary_accuracy: 0.9709
# Epoch 00045: loss did not improve from -0.95265
# 302/302 [==============================] - 59s 196ms/step - loss: -0.9524 - dice_coef: 0.9524 - binary_accuracy: 0.9709 - val_loss: -0.9643 - val_dice_coef: 0.9643 - val_binary_accuracy: 0.9844
# Epoch 46/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9535 - dice_coef: 0.9535 - binary_accuracy: 0.9717
# Epoch 00046: loss improved from -0.95265 to -0.95353, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9535 - dice_coef: 0.9535 - binary_accuracy: 0.9717 - val_loss: -0.9545 - val_dice_coef: 0.9545 - val_binary_accuracy: 0.9802
# Epoch 47/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9540 - dice_coef: 0.9540 - binary_accuracy: 0.9720
# Epoch 00047: loss improved from -0.95353 to -0.95396, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9540 - dice_coef: 0.9540 - binary_accuracy: 0.9720 - val_loss: -0.9616 - val_dice_coef: 0.9616 - val_binary_accuracy: 0.9832
# Epoch 48/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9551 - dice_coef: 0.9551 - binary_accuracy: 0.9725
# Epoch 00048: loss improved from -0.95396 to -0.95507, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 61s 204ms/step - loss: -0.9551 - dice_coef: 0.9551 - binary_accuracy: 0.9725 - val_loss: -0.9610 - val_dice_coef: 0.9610 - val_binary_accuracy: 0.9825
# Epoch 49/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9545 - dice_coef: 0.9545 - binary_accuracy: 0.9723
# Epoch 00049: loss did not improve from -0.95507
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9545 - dice_coef: 0.9545 - binary_accuracy: 0.9723 - val_loss: -0.9639 - val_dice_coef: 0.9639 - val_binary_accuracy: 0.9841
# Epoch 50/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9542 - dice_coef: 0.9542 - binary_accuracy: 0.9720
# Epoch 00050: loss did not improve from -0.95507
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9542 - dice_coef: 0.9542 - binary_accuracy: 0.9720 - val_loss: -0.9717 - val_dice_coef: 0.9717 - val_binary_accuracy: 0.9870
# Epoch 51/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9552 - dice_coef: 0.9552 - binary_accuracy: 0.9726
# Epoch 00051: loss improved from -0.95507 to -0.95523, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 61s 202ms/step - loss: -0.9552 - dice_coef: 0.9552 - binary_accuracy: 0.9726 - val_loss: -0.9627 - val_dice_coef: 0.9627 - val_binary_accuracy: 0.9838
# Epoch 52/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9546 - dice_coef: 0.9546 - binary_accuracy: 0.9724
# Epoch 00052: loss did not improve from -0.95523
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9546 - dice_coef: 0.9546 - binary_accuracy: 0.9724 - val_loss: -0.9603 - val_dice_coef: 0.9603 - val_binary_accuracy: 0.9814
# Epoch 53/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9556 - dice_coef: 0.9556 - binary_accuracy: 0.9729
# Epoch 00053: loss improved from -0.95523 to -0.95556, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9556 - dice_coef: 0.9556 - binary_accuracy: 0.9729 - val_loss: -0.9550 - val_dice_coef: 0.9550 - val_binary_accuracy: 0.9805
# Epoch 54/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9555 - dice_coef: 0.9555 - binary_accuracy: 0.9729
# Epoch 00054: loss did not improve from -0.95556
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9555 - dice_coef: 0.9555 - binary_accuracy: 0.9729 - val_loss: -0.9666 - val_dice_coef: 0.9666 - val_binary_accuracy: 0.9845
# Epoch 55/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9567 - dice_coef: 0.9567 - binary_accuracy: 0.9737
# Epoch 00055: loss improved from -0.95556 to -0.95669, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9567 - dice_coef: 0.9567 - binary_accuracy: 0.9737 - val_loss: -0.9720 - val_dice_coef: 0.9720 - val_binary_accuracy: 0.9876
# Epoch 56/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9561 - dice_coef: 0.9561 - binary_accuracy: 0.9733
# Epoch 00056: loss did not improve from -0.95669
# 302/302 [==============================] - 59s 196ms/step - loss: -0.9561 - dice_coef: 0.9561 - binary_accuracy: 0.9733 - val_loss: -0.9503 - val_dice_coef: 0.9503 - val_binary_accuracy: 0.9778
# Epoch 57/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9570 - dice_coef: 0.9570 - binary_accuracy: 0.9737
# Epoch 00057: loss improved from -0.95669 to -0.95697, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9570 - dice_coef: 0.9570 - binary_accuracy: 0.9737 - val_loss: -0.9703 - val_dice_coef: 0.9703 - val_binary_accuracy: 0.9864
# Epoch 58/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9569 - dice_coef: 0.9569 - binary_accuracy: 0.9737
# Epoch 00058: loss did not improve from -0.95697
# 302/302 [==============================] - 59s 196ms/step - loss: -0.9569 - dice_coef: 0.9569 - binary_accuracy: 0.9737 - val_loss: -0.9711 - val_dice_coef: 0.9711 - val_binary_accuracy: 0.9871
# Epoch 59/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9571 - dice_coef: 0.9571 - binary_accuracy: 0.9737
# Epoch 00059: loss improved from -0.95697 to -0.95711, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9571 - dice_coef: 0.9571 - binary_accuracy: 0.9737 - val_loss: -0.9018 - val_dice_coef: 0.9018 - val_binary_accuracy: 0.9594
# Epoch 60/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9563 - dice_coef: 0.9563 - binary_accuracy: 0.9734
# Epoch 00060: loss did not improve from -0.95711
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9563 - dice_coef: 0.9563 - binary_accuracy: 0.9734 - val_loss: -0.9741 - val_dice_coef: 0.9741 - val_binary_accuracy: 0.9882
# Epoch 61/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9577 - dice_coef: 0.9577 - binary_accuracy: 0.9742
# Epoch 00061: loss improved from -0.95711 to -0.95766, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 62s 204ms/step - loss: -0.9577 - dice_coef: 0.9577 - binary_accuracy: 0.9742 - val_loss: -0.9606 - val_dice_coef: 0.9606 - val_binary_accuracy: 0.9815
# Epoch 62/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9583 - dice_coef: 0.9583 - binary_accuracy: 0.9744
# Epoch 00062: loss improved from -0.95766 to -0.95826, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 63s 208ms/step - loss: -0.9583 - dice_coef: 0.9583 - binary_accuracy: 0.9744 - val_loss: -0.9702 - val_dice_coef: 0.9702 - val_binary_accuracy: 0.9865
# Epoch 63/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9578 - dice_coef: 0.9578 - binary_accuracy: 0.9742
# Epoch 00063: loss did not improve from -0.95826
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9578 - dice_coef: 0.9578 - binary_accuracy: 0.9742 - val_loss: -0.9748 - val_dice_coef: 0.9748 - val_binary_accuracy: 0.9886
# Epoch 64/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9587 - dice_coef: 0.9587 - binary_accuracy: 0.9747
# Epoch 00064: loss improved from -0.95826 to -0.95875, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9587 - dice_coef: 0.9587 - binary_accuracy: 0.9747 - val_loss: -0.9721 - val_dice_coef: 0.9721 - val_binary_accuracy: 0.9872
# Epoch 65/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9582 - dice_coef: 0.9582 - binary_accuracy: 0.9745
# Epoch 00065: loss did not improve from -0.95875
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9582 - dice_coef: 0.9582 - binary_accuracy: 0.9745 - val_loss: -0.9618 - val_dice_coef: 0.9618 - val_binary_accuracy: 0.9824
# Epoch 66/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9586 - dice_coef: 0.9586 - binary_accuracy: 0.9747
# Epoch 00066: loss did not improve from -0.95875
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9586 - dice_coef: 0.9586 - binary_accuracy: 0.9747 - val_loss: -0.9693 - val_dice_coef: 0.9693 - val_binary_accuracy: 0.9862
# Epoch 67/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9597 - dice_coef: 0.9597 - binary_accuracy: 0.9754
# Epoch 00067: loss improved from -0.95875 to -0.95974, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9597 - dice_coef: 0.9597 - binary_accuracy: 0.9754 - val_loss: -0.9720 - val_dice_coef: 0.9720 - val_binary_accuracy: 0.9873
# Epoch 68/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9588 - dice_coef: 0.9588 - binary_accuracy: 0.9749
# Epoch 00068: loss did not improve from -0.95974
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9588 - dice_coef: 0.9588 - binary_accuracy: 0.9749 - val_loss: -0.9741 - val_dice_coef: 0.9741 - val_binary_accuracy: 0.9883
# Epoch 69/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9594 - dice_coef: 0.9594 - binary_accuracy: 0.9751
# Epoch 00069: loss did not improve from -0.95974
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9594 - dice_coef: 0.9594 - binary_accuracy: 0.9751 - val_loss: -0.9703 - val_dice_coef: 0.9703 - val_binary_accuracy: 0.9868
# Epoch 70/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9596 - dice_coef: 0.9596 - binary_accuracy: 0.9753
# Epoch 00070: loss did not improve from -0.95974
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9596 - dice_coef: 0.9596 - binary_accuracy: 0.9753 - val_loss: -0.9722 - val_dice_coef: 0.9722 - val_binary_accuracy: 0.9875
# Epoch 71/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9600 - dice_coef: 0.9600 - binary_accuracy: 0.9756
# Epoch 00071: loss improved from -0.95974 to -0.95996, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9600 - dice_coef: 0.9600 - binary_accuracy: 0.9756 - val_loss: -0.9676 - val_dice_coef: 0.9676 - val_binary_accuracy: 0.9854
# Epoch 72/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9599 - dice_coef: 0.9599 - binary_accuracy: 0.9756
# Epoch 00072: loss did not improve from -0.95996
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9599 - dice_coef: 0.9599 - binary_accuracy: 0.9756 - val_loss: -0.9740 - val_dice_coef: 0.9740 - val_binary_accuracy: 0.9882
# Epoch 73/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9591 - dice_coef: 0.9591 - binary_accuracy: 0.9751
# Epoch 00073: loss did not improve from -0.95996
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9591 - dice_coef: 0.9591 - binary_accuracy: 0.9751 - val_loss: -0.9704 - val_dice_coef: 0.9704 - val_binary_accuracy: 0.9862
# Epoch 74/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9587 - dice_coef: 0.9587 - binary_accuracy: 0.9748
# Epoch 00074: loss did not improve from -0.95996
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9587 - dice_coef: 0.9587 - binary_accuracy: 0.9748 - val_loss: -0.9753 - val_dice_coef: 0.9753 - val_binary_accuracy: 0.9886
# Epoch 75/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9603 - dice_coef: 0.9603 - binary_accuracy: 0.9757
# Epoch 00075: loss improved from -0.95996 to -0.96033, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9603 - dice_coef: 0.9603 - binary_accuracy: 0.9757 - val_loss: -0.9757 - val_dice_coef: 0.9757 - val_binary_accuracy: 0.9889
# Epoch 76/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9604 - dice_coef: 0.9604 - binary_accuracy: 0.9759
# Epoch 00076: loss improved from -0.96033 to -0.96043, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9604 - dice_coef: 0.9604 - binary_accuracy: 0.9759 - val_loss: -0.9717 - val_dice_coef: 0.9717 - val_binary_accuracy: 0.9871
# Epoch 77/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9601 - dice_coef: 0.9601 - binary_accuracy: 0.9754
# Epoch 00077: loss did not improve from -0.96043
# 302/302 [==============================] - 61s 201ms/step - loss: -0.9601 - dice_coef: 0.9601 - binary_accuracy: 0.9754 - val_loss: -0.9564 - val_dice_coef: 0.9564 - val_binary_accuracy: 0.9796
# Epoch 78/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9597 - dice_coef: 0.9597 - binary_accuracy: 0.9754
# Epoch 00078: loss did not improve from -0.96043
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9597 - dice_coef: 0.9597 - binary_accuracy: 0.9754 - val_loss: -0.9724 - val_dice_coef: 0.9724 - val_binary_accuracy: 0.9873
# Epoch 79/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9606 - dice_coef: 0.9606 - binary_accuracy: 0.9760
# Epoch 00079: loss improved from -0.96043 to -0.96063, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9606 - dice_coef: 0.9606 - binary_accuracy: 0.9760 - val_loss: -0.9711 - val_dice_coef: 0.9711 - val_binary_accuracy: 0.9870
# Epoch 80/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9605 - dice_coef: 0.9605 - binary_accuracy: 0.9759
# Epoch 00080: loss did not improve from -0.96063
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9605 - dice_coef: 0.9605 - binary_accuracy: 0.9759 - val_loss: -0.9747 - val_dice_coef: 0.9747 - val_binary_accuracy: 0.9884
# Epoch 81/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9612 - dice_coef: 0.9612 - binary_accuracy: 0.9762
# Epoch 00081: loss improved from -0.96063 to -0.96116, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9612 - dice_coef: 0.9612 - binary_accuracy: 0.9762 - val_loss: -0.9726 - val_dice_coef: 0.9726 - val_binary_accuracy: 0.9878
# Epoch 82/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9614 - dice_coef: 0.9614 - binary_accuracy: 0.9763
# Epoch 00082: loss improved from -0.96116 to -0.96136, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 199ms/step - loss: -0.9614 - dice_coef: 0.9614 - binary_accuracy: 0.9763 - val_loss: -0.9683 - val_dice_coef: 0.9683 - val_binary_accuracy: 0.9854
# Epoch 83/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9612 - dice_coef: 0.9612 - binary_accuracy: 0.9765
# Epoch 00083: loss did not improve from -0.96136
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9612 - dice_coef: 0.9612 - binary_accuracy: 0.9765 - val_loss: -0.9711 - val_dice_coef: 0.9711 - val_binary_accuracy: 0.9869
# Epoch 84/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9599 - dice_coef: 0.9599 - binary_accuracy: 0.9755
# Epoch 00084: loss did not improve from -0.96136
# 302/302 [==============================] - 59s 196ms/step - loss: -0.9599 - dice_coef: 0.9599 - binary_accuracy: 0.9755 - val_loss: -0.9730 - val_dice_coef: 0.9730 - val_binary_accuracy: 0.9875
# Epoch 85/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9606 - dice_coef: 0.9606 - binary_accuracy: 0.9760
# Epoch 00085: loss did not improve from -0.96136
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9606 - dice_coef: 0.9606 - binary_accuracy: 0.9760 - val_loss: -0.9690 - val_dice_coef: 0.9690 - val_binary_accuracy: 0.9856
# Epoch 86/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9626 - dice_coef: 0.9626 - binary_accuracy: 0.9769
# Epoch 00086: loss improved from -0.96136 to -0.96260, saving model to /content/drive/MyDrive/3차플젝drive/test/check/unet_lung_seg.hdf5
# 302/302 [==============================] - 60s 200ms/step - loss: -0.9626 - dice_coef: 0.9626 - binary_accuracy: 0.9769 - val_loss: -0.9744 - val_dice_coef: 0.9744 - val_binary_accuracy: 0.9883
# Epoch 87/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9619 - dice_coef: 0.9619 - binary_accuracy: 0.9767
# Epoch 00087: loss did not improve from -0.96260
# 302/302 [==============================] - 60s 198ms/step - loss: -0.9619 - dice_coef: 0.9619 - binary_accuracy: 0.9767 - val_loss: -0.9767 - val_dice_coef: 0.9767 - val_binary_accuracy: 0.9892
# Epoch 88/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9621 - dice_coef: 0.9621 - binary_accuracy: 0.9768
# Epoch 00088: loss did not improve from -0.96260
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9621 - dice_coef: 0.9621 - binary_accuracy: 0.9768 - val_loss: -0.9735 - val_dice_coef: 0.9735 - val_binary_accuracy: 0.9877
# Epoch 89/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9617 - dice_coef: 0.9617 - binary_accuracy: 0.9766
# Epoch 00089: loss did not improve from -0.96260
# 302/302 [==============================] - 61s 201ms/step - loss: -0.9617 - dice_coef: 0.9617 - binary_accuracy: 0.9766 - val_loss: -0.9776 - val_dice_coef: 0.9776 - val_binary_accuracy: 0.9897
# Epoch 90/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9620 - dice_coef: 0.9620 - binary_accuracy: 0.9767
# Epoch 00090: loss did not improve from -0.96260
# 302/302 [==============================] - 59s 197ms/step - loss: -0.9620 - dice_coef: 0.9620 - binary_accuracy: 0.9767 - val_loss: -0.9797 - val_dice_coef: 0.9797 - val_binary_accuracy: 0.9906
# Epoch 91/100
# 302/302 [==============================] - ETA: 0s - loss: -0.9621 - dice_coef: 0.9621 - binary_accuracy: 0.9768
# Epoch 00091: loss did not improve from -0.96260
# 302/302 [==============================] - 60s 197ms/step - loss: -0.9621 - dice_coef: 0.9621 - binary_accuracy: 0.9768 - val_loss: -0.9762 - val_dice_coef: 0.9762 - val_binary_accuracy: 0.9892

# %%
from tensorflow.keras.models import load_model

model.save('/content/drive/MyDrive/3차플젝drive/test/model/unet_2_100.h5')

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

training_accuracy = history.history['binary_accuracy']
validation_accuracy = history.history['val_binary_accuracy']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_loss, 'r--')
axs[0].plot(epoch_count, validation_loss, 'b-')
axs[0].legend(['Training Loss', 'Validation Loss'])

axs[1].plot(epoch_count, training_accuracy, 'r--')
axs[1].plot(epoch_count, validation_accuracy, 'b-')
axs[1].legend(['Training Accuracy', 'Validation Accuracy'])

# %%
test_gen = test_generator(test_files, target_size=(512,512))
results = model.predict_generator(test_gen, len(test_files), verbose=1)
save_result(SEGMENTATION_TEST_DIR, results, test_files)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# 100/100 [==============================] - 2s 14ms/step

# %%
from tensorflow.keras.models import load_model

model.save('/content/drive/MyDrive/3차플젝drive/test/model/unet_2_100_2.h5')

# %% [markdown]
# #### MODEL LOAD

# %%
import tensorflow
model = tensorflow.keras.models.load_model('/content/drive/MyDrive/3차플젝drive/test/model/unet_2_100.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ad2b3d88be4f> in <module>()
#       1 import tensorflow
# ----> 2 model = tensorflow.keras.models.load_model('/content/drive/MyDrive/3차플젝drive/test/model/unet_2_100.h5')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     707       if obj is None:
#     708         raise ValueError(
# --> 709             f'Unknown {printable_module_name}: {object_name}. Please ensure '
#     710             'this object is passed to the `custom_objects` argument. See '
#     711             'https://www.tensorflow.org/guide/keras/save_and_serialize'
#
# ValueError: Unknown loss function: dice_coef_loss. Please ensure this object is passed to the `custom_objects` argument. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %% [markdown]
# ### TEST PREDICTION

# %%
image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/CHNCXR_0014_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/CHNCXR_0014_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/CHNCXR_0014_0_mask.png")

fig, axs = plt.subplots(4, 3, figsize=(16, 16))

axs[0, 0].set_title("Predicted")
axs[0, 0].imshow(add_colored_mask(image, predict_image))
axs[0, 1].set_title("Gold Std.")
axs[0, 1].imshow(add_colored_mask(image, mask_image))
axs[0, 2].set_title("Diff.")
axs[0, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/MCUCXR_0002_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/MCUCXR_0002_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/MCUCXR_0002_0_mask.png")

axs[1, 0].set_title("Predicted")
axs[1, 0].imshow(add_colored_mask(image, predict_image))
axs[1, 1].set_title("Gold Std.")
axs[1, 1].imshow(add_colored_mask(image, mask_image))
axs[1, 2].set_title("Diff.")
axs[1, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/CHNCXR_0237_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/CHNCXR_0237_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/CHNCXR_0237_0_mask.png")

axs[2, 0].set_title("Predicted")
axs[2, 0].imshow(add_colored_mask(image, predict_image))
axs[2, 1].set_title("Gold Std.")
axs[2, 1].imshow(add_colored_mask(image, mask_image))
axs[2, 2].set_title("Diff.")
axs[2, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/MCUCXR_0084_0.png")
predict_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/MCUCXR_0084_0_predict.png")
mask_image = cv2.imread("/content/drive/MyDrive/3차플젝drive/test/KAGGLE/Segment/input/segmentation/test/MCUCXR_0084_0_mask.png")

axs[3, 0].set_title("Predicted")
axs[3, 0].imshow(add_colored_mask(image, predict_image))
axs[3, 1].set_title("Gold Std.")
axs[3, 1].imshow(add_colored_mask(image, mask_image))
axs[3, 2].set_title("Diff.")
axs[3, 2].imshow(diff_mask(mask_image, predict_image))

# %% [markdown]
# ### REAL TEST_KAGGLE

# %%
import cv2
t_file = '/content/drive/MyDrive/3차플젝drive/test/t'
files = glob(os.path.join(t_file, "*.jpg"))
save_dir = '/content/drive/MyDrive/3차플젝drive/test/t/predict'

# %%
t_gen= test_generator(files, target_size=(512,512))
B = model.predict_generator(t_gen, len(files), verbose=1)
save_result(save_dir, B, files)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# 3/3 [==============================] - 1s 345ms/step

# %%
og_img_path = '/content/drive/MyDrive/3차플젝drive/test/t/00d7c36e-3cdf-4df6-ac03-6c30cdc8e85b.jpg'
mask_path = '/content/drive/MyDrive/3차플젝drive/test/t/predict/00d7c36e-3cdf-4df6-ac03-6c30cdc8e85b_predict.jpg'
size = (512,512)

og_img = cv2.imread(og_img_path)
mask_img = cv2.imread(mask_path)

# kernel = np.ones((3,3),np.uint8)
# erode = cv2.erode(mask_img,kernel,iterations=5)

remove = rv_3ch(og_img_path, mask_path, size)
plt.figure(figsize=(30,20))


plt.subplot(131)
plt.imshow(og_img)

plt.subplot(132)
plt.imshow(mask_img)

plt.subplot(133)
plt.imshow(remove)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def rv_3ch(og_img_path, mask_path, size):
    
    #module import
    import cv2
    
    # im_read
    og_img = cv2.imread(og_img_path)
    mask = cv2.imread(mask_path)
    
    # clahe
    clahe = cv2.createCLAHE(5.0,(12,12))
    
    ## og_img_convert
    cvt_img = cv2.resize(og_img, size)
    cvt_img = cv2.cvtColor(cvt_img,cv2.COLOR_BGR2GRAY)
    cvt_img = clahe.apply(cvt_img)  # 1 channel
    cvt_img = np.repeat(cvt_img[:,:,np.newaxis],3,-1)

    ## mask
    cvt_mask = cv2.resize(mask, size)
    cvt_mask = cv2.cvtColor(cvt_mask, cv2.COLOR_BGR2GRAY)

    ## remove
    remove = cv2.bitwise_and(cvt_img, cvt_img, mask = cvt_mask)
    
    return remove

# %%
import pandas as pd
total_data = pd.read_csv('/content/drive/MyDrive/3차플젝drive/공모전_이전_캐글/PD/total_file.csv',index_col=0)
a = list(total_data['id'])
len(a)

# %%
from glob import glob
og_train_path = '/content/drive/MyDrive/3차플젝drive/공모전_이전_캐글/PD/penumonia/stage_2_train_images/'
og_tr_list = glob(og_train_path + "*.dcm")
len(og_tr_list)

# %%
tr_normal_path ='/content/drive/MyDrive/3차플젝drive/공모전_이전_캐글/PD/penumonia/원본트레인전체이미지/'
tr_normal_list = glob(tr_normal_path + '*.jpg')

tr_pneu_path = '/content/drive/MyDrive/3차플젝drive/공모전_이전_캐글/PD/penumonia/원본트레인전체이미지/pneumonia/'
tr_pneu_list = glob(tr_pneu_path+"*.jpg")

print(len(tr_normal_list))
print(len(tr_pneu_list))

# %%
normal_files = glob('/content/drive/.shortcut-targets-by-id/1BX4a76ZgAV3v_4f92zIjOVpwJ6RMMxJZ/3차플젝drive/공모전_이전_캐글/PD/penumonia/원본트레인전체이미지/normal/' + '*.jpg')
pneu_files = glob('/content/drive/.shortcut-targets-by-id/1BX4a76ZgAV3v_4f92zIjOVpwJ6RMMxJZ/3차플젝drive/공모전_이전_캐글/PD/penumonia/원본트레인전체이미지/pneumonia/' + '*.jpg')

# %%
ls

# %%
import tensorflow
model = tensorflow.keras.models.load_model('/content/drive/MyDrive/3차플젝drive/test/unet_8_30.h5', compile=False)

# %%
import cv2
t_file = '/content/drive/MyDrive/3차플젝drive/test/t'
files = glob(os.path.join(t_file, "*.jpg"))
save_dir = '/content/drive/MyDrive/3차플젝drive/test/t/predict'
t_gen= test_generator(files, target_size=(512,512))
B = model.predict_generator(t_gen, len(files), verbose=1)
save_result(save_dir, B, files)
