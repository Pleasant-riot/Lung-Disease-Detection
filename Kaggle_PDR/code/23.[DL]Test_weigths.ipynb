# %%
# !git clone https://github.com/arnoweng/CheXNet.git

# %%
import sys
sys.path.append('/content/CheXNet')

# %%
import model

# %%
import model

model.main()

# %%
pwd

# %%
/content/CheXNet/ChestX-ray14/labels/test_list.txt
